# %%
# !pip install mysql-connector-python sqlalchemy pymysql
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\admin\desktop\lib\site-packages (9.5.0)
# Requirement already satisfied: sqlalchemy in c:\users\admin\desktop\lib\site-packages (2.0.44)
# Requirement already satisfied: pymysql in c:\users\admin\desktop\lib\site-packages (1.1.2)
# Requirement already satisfied: greenlet>=1 in c:\users\admin\desktop\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\admin\desktop\lib\site-packages (from sqlalchemy) (4.15.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pandas requests beautifulsoup4 yfinance tqdm
# Out:
# Requirement already satisfied: pandas in c:\users\admin\desktop\lib\site-packages (2.3.3)
# Requirement already satisfied: requests in c:\users\admin\desktop\lib\site-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\admin\desktop\lib\site-packages (4.14.2)
# Requirement already satisfied: yfinance in c:\users\admin\desktop\lib\site-packages (0.2.66)
# Requirement already satisfied: tqdm in c:\users\admin\desktop\lib\site-packages (4.67.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\desktop\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\desktop\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\desktop\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\desktop\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\desktop\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\desktop\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\desktop\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\desktop\lib\site-packages (from requests) (2025.11.12)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\desktop\lib\site-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\admin\desktop\lib\site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\admin\desktop\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\admin\desktop\lib\site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\admin\desktop\lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\admin\desktop\lib\site-packages (from yfinance) (3.18.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\admin\desktop\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\admin\desktop\lib\site-packages (from yfinance) (6.33.1)
# Requirement already satisfied: websockets>=13.0 in c:\users\admin\desktop\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: colorama in c:\users\admin\desktop\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\admin\desktop\lib\site-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\admin\desktop\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: six>=1.5 in c:\users\admin\desktop\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
## HAM 1: CRAWL ALL

import requests
import pandas as pd
from io import StringIO
from concurrent.futures import ThreadPoolExecutor, as_completed
import numpy as np
import re

# --- Cấu hình ---
API_URL = 'https://inav.ice.com/api/1/tse/iopv/table?type=etf&language=en'
HEADERS = {'User-Agent': 'Mozilla/5.0', 'Referer': 'https://inav.ice.com'}
URL_TEMPLATE = "https://inav.ice.com/pcf-download/{code}.csv"
MAX_WORKERS = 12

# Hàm get_etf_codes
def get_etf_codes():
    """Lấy danh sách các ETF code hợp lệ từ API."""
    try:
        r = requests.get(API_URL, headers=HEADERS, timeout=10)
        r.raise_for_status()
        rows = r.json().get("rows", [])
        return [row["code"] for row in rows if row.get("code", "")]
    except requests.RequestException as e:
        print(f"⚠️ Lỗi khi lấy ETF codes từ API: {e}")
        return []

# Hàm parse_etf_csv
def parse_etf_csv(etf_code):
    """Tải và phân tích file CSV cho một ETF code, tính toán Value và thêm metadata."""
    url = URL_TEMPLATE.format(code=etf_code)
    shares_out = np.nan
    fund_date = np.nan
    
    try:
        r = requests.get(url, headers=HEADERS, timeout=10)
        r.raise_for_status()
        text = r.text
        
        # 1. Đọc metadata (dòng 2)
        meta = pd.read_csv(StringIO(text), skiprows=1, nrows=1, header=None)
        
        if meta.shape[1] >= 4: 
            shares_out = meta.iloc[0, 3]
        if meta.shape[1] >= 5: 
            fund_date = meta.iloc[0, 4]

        # 2. Đọc holdings (bắt đầu từ dòng 4)
        df = pd.read_csv(StringIO(text), skiprows=3)

        # 3. Đổi tên cột và chuẩn hóa
        df.rename(columns={
            "Shares Amount": "Shares_Amount",
            "Stock Price": "Stock_Price"
        }, inplace=True, errors='ignore')

        if 'Shares_Amount' not in df.columns or 'Stock_Price' not in df.columns:
             raise KeyError("Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV.")
        
        # 4. Chuyển đổi numeric
        df["Shares_Amount"] = pd.to_numeric(df["Shares_Amount"], errors="coerce")
        df["Stock_Price"] = pd.to_numeric(df["Stock_Price"], errors="coerce")
        df = df.dropna(subset=["Shares_Amount", "Stock_Price"])

        # 5. Tính toán và thêm metadata
        if df.empty:
            return None
            
        df["Value"] = df["Shares_Amount"] * df["Stock_Price"]
        df["ETF_Code"] = str(etf_code)
        df["Shares_Outstanding"] = shares_out
        df["Fund_Date"] = fund_date
        
        # 6. Sắp xếp thứ tự cột
        final_columns = ["ETF_Code", "Code", "Name", "ISIN", "Exchange", "Currency",
                         "Shares_Amount", "Stock_Price", "Value", "Shares_Outstanding", "Fund_Date"]

        for col in final_columns:
            if col not in df.columns:
                df[col] = np.nan 

        return df[final_columns]

    except requests.exceptions.HTTPError as e:
        print(f"⚠️ Lỗi HTTP cho {etf_code}: Không tìm thấy file CSV ({e})")
        return None
    except KeyError as e:
        print(f"⚠️ Lỗi Key/Cột cho {etf_code}: Cột dữ liệu chính bị thiếu. {e}")
        return None
    except Exception as e:
        print(f"⚠️ Lỗi phân tích cú pháp/khác cho {etf_code}: {e}")
        return None

# --- MAIN Execution
def main():
    """Chạy chương trình chính: lấy codes, tải, phân tích, hợp nhất và in ra toàn bộ DataFrame."""
    
    codes_list = get_etf_codes()
    if not codes_list:
        print("Không có ETF codes nào được tải xuống.")
        return None

    results_map = {}
    print(f"Đang xử lý {len(codes_list)} ETF codes...")

    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as ex:
        futures = {ex.submit(parse_etf_csv, code): code for code in codes_list}
        
        for i, future in enumerate(as_completed(futures), 1):
            code = futures[future]
            df = future.result()
            
            if df is not None:
                results_map[code] = df
            
            print(f"[{i}/{len(codes_list)}] Đã xử lý code {code}.", end='\r', flush=True)

    print("\n--- Hoàn tất tải và phân tích ---")

    sorted_data = []
    for code in codes_list:
        if code in results_map:
            sorted_data.append(results_map[code])

    if sorted_data:
        df_final_detail = pd.concat(sorted_data, ignore_index=True)
        
    

        print(f"\n✅ Xong. Đã tạo DataFrame **df_final_detail** với {len(df_final_detail)} holdings.")
        print("\n--- df_final_detail (TOÀN BỘ NỘI DUNG) ---")
        
               
        return df_final_detail
        
    else:
        print("Không có DataFrame hợp lệ nào để hiển thị.")
        return None

if __name__ == "__main__":
    df_final_detail = main()
# Out:
# Đang xử lý 386 ETF codes...
# ⚠️ Lỗi Key/Cột cho 1326: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1308: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1305: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1322: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."⚠️ Lỗi Key/Cột cho 1309: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
#
# ⚠️ Lỗi Key/Cột cho 1320: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1345: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 133A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1330: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1358: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1349: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1365: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1367: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1368: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1366: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1399: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1457: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 140A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1456: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1466: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1479: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1481: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1486: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1487: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1488: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1490: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1496: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1495: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1497: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1540: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1542: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1543: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1541: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1547: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1554: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1555: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1557: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1566: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1578: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1585: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1586: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1592: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1599: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1651: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1654: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1652: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1653: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# [125/386] Đã xử lý code 1656.⚠️ Lỗi Key/Cột cho 1657: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1658: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1659: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1671: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1672: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1673: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1674: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1675: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1676: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1681: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1680: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1677: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1679: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1684: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1685: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1686: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1687: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1688: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1690: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1689: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1691: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1694: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1692: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1695: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1693: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1696: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1697: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 1698: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 178A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 188A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2013: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2014: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2015: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2016: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2017: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2018: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2019: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 201A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2087: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2086: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2088: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2089: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2090: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2093: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2092: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2091: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2096: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2097: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2095: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2098: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 210A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 213A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2235: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2237: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2236: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2238: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2239: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 223A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2240: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2243: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2244: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 224A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2249: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2248: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."⚠️ Lỗi Key/Cột cho 2247: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
#
# ⚠️ Lỗi Key/Cột cho 2252: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2253: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2254: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2256: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2257: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2258: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 235A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 234A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 233A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2522: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2521: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2528: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2530: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2552: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2565: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2566: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2562: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2564: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2569: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2568: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2622: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2623: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2624: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2625: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2626: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2627: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2629: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2628: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2636: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2637: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2638: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2640: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2641: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2639: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2644: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2645: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2646: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2836: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2837: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 282A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 283A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2840: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2841: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2842: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2844: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2843: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2847: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2849: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2848: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2854: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2855: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2861: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2862: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2864: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2866: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2865: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2868: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2867: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2869: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 2870: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 315A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 316A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 318A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 328A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 354A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 356A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 363A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 379A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 381A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 382A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 399A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 413A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 424A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 426A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 425A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 435A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 443A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 465A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 466A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 467A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# ⚠️ Lỗi Key/Cột cho 468A: Cột dữ liệu chính bị thiếu. "Cột 'Shares_Amount' hoặc 'Stock_Price' không tìm thấy trong file CSV."
# [386/386] Đã xử lý code 468A.
# --- Hoàn tất tải và phân tích ---
#
# ✅ Xong. Đã tạo DataFrame **df_final_detail** với 45119 holdings.
#
# --- df_final_detail (TOÀN BỘ NỘI DUNG) ---

# %%
## HAM 2: XU LI SAU CRAWL

df_final_detail.rename(columns={
    'Code' : 'code',
    'Name' : 'name',
    'Exchange' : 'exchange',
    'Currency' : 'currency',
    'Shares_Amount' : 'shares_amount',
    'Stock_Price' : 'stock_price',
    'Value' : 'value',
    'Shares_Outstanding' : 'shares_outstanding',
    'Fund_Date' : 'fund_date',
    'ISIN' : 'isin'})

df_final_detail = df_final_detail[
    [ "Code" , "Name", "Exchange", "Currency", "Shares_Amount", "Stock_Price" , "Value" , "ETF_Code" , "Fund_Date", "Shares_Outstanding" , "ISIN"]]

df_final_detail['Shares_Amount'] = df_final_detail['Shares_Amount'].astype(int)
df_final_detail['Shares_Outstanding'] = df_final_detail['Shares_Outstanding'].astype(int)
df_final_detail['Fund_Date'] = pd.to_datetime(df_final_detail['Fund_Date'], format='%Y%m%d')
df_final_detail.rename(columns={'ETF_Code' : 'etf_code'},inplace=True)

# %%
df_final_detail
# Out:
#          Code                Name Exchange Currency  Shares_Amount  \
# 0         NaN          TOPIX 2512      OSE      JPY          16756
# 1        1301      KYOKUYO CO LTD      TSE      JPY         346100
# 2        1332  NISSUI CORPORATION      TSE      JPY        7576000
# 3        1333  MARUHA NICHIRO COR      TSE      JPY        1337800
# 4        1375    YUKIGUNI FACTORY      TSE      JPY         703900
# ...       ...                 ...      ...      ...            ...
# 45114  8750.0  DAI-ICHI LIFE HOLD      TSE      JPY          16500
# 45115  8795.0    T&D HOLDINGS INC      TSE      JPY           4300
# 45116  9101.0     NIPPON YUSEN KK      TSE      JPY           3800
# 45117  9107.0  KAWASAKI KISEN KAI      TSE      JPY          10000
# 45118  9502.0    CHUBU ELEC POWER      TSE      JPY           3900
#
#        Stock_Price         Value etf_code  Fund_Date  Shares_Outstanding  \
# 0           3328.0  5.576397e+07     1306 2025-12-04          8141966522
# 1           4615.0  1.597252e+09     1306 2025-12-04          8141966522
# 2           1216.5  9.216204e+09     1306 2025-12-04          8141966522
# 3           3707.0  4.959225e+09     1306 2025-12-04          8141966522
# 4           1040.0  7.320560e+08     1306 2025-12-04          8141966522
# ...            ...           ...      ...        ...                 ...
# 45114       1226.0  2.022961e+07     461A 2025-12-04              294900
# 45115       3464.0  1.489565e+07     461A 2025-12-04              294900
# 45116       4836.0  1.837736e+07     461A 2025-12-04              294900
# 45117       2063.0  2.063062e+07     461A 2025-12-04              294900
# 45118       2327.5  9.077524e+06     461A 2025-12-04              294900
#
#                ISIN
# 0               NaN
# 1      JP3257200000
# 2      JP3718800000
# 3      JP3876600002
# 4      JP3947010009
# ...             ...
# 45114  JP3476480003
# 45115  JP3539220008
# 45116  JP3753000003
# 45117  JP3223800008
# 45118  JP3526600006
#
# [45119 rows x 11 columns]

# %%
df_final_detail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45119 entries, 0 to 45118
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Code                43772 non-null  object
#  1   Name                44973 non-null  object
#  2   Exchange            44217 non-null  object
#  3   Currency            45119 non-null  object
#  4   Shares_Amount       45119 non-null  int64
#  5   Stock_Price         45119 non-null  float64
#  6   Value               45119 non-null  float64
#  7   etf_code            45119 non-null  object
#  8   Fund_Date           45119 non-null  datetime64[ns]
#  9   Shares_Outstanding  45119 non-null  int64
#  10  ISIN                44927 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(6)
# memory usage: 3.8+ MB

# %%
import mysql.connector

# %%
## HAM 3: KET NOI MYSQL


import mysql.connector
cnx = mysql.connector.connect(
    user='root',               # đổi theo MySQL của bạn
    password='Phunghainam2004!',
    host='127.0.0.1',
    database='train'
)
cursor = cnx.cursor()

# --- Mapping DataFrame -> MySQL ---
# key = tên cột trong DataFrame, value = tên cột trong MySQL
col_mapping = {
    "Code" : "Code",
    "Name" : "Name",
    "Exchange" : "Exchange",
    "Currency" : "Currency",
    "Shares_Amount" :"Shares_Amount",
    "Stock_Price" : "Stock_Price",
    "Value" : "Value",
    "etf_code" : "etf_code",
    "Fund_Date" : "Fund_Date",
    "Shares_Outstanding" : "Shares_Outstanding",
    "ISIN" : "ISIN"    
}

# Lấy danh sách cột từ DataFrame và bảng
df_cols = list(col_mapping.keys())
table_cols = [col_mapping[c] for c in df_cols]

# --- Tạo câu SQL ---
col_str = ",".join([f"`{c}`" for c in table_cols])
placeholder_str = ",".join(["%s"] * len(df_cols))
sql = f"INSERT INTO `etf_asset_detail_train` ({col_str}) VALUES ({placeholder_str})"

# --- Insert từng dòng ---
for row in df_final_detail[df_cols].itertuples(index=False, name=None):
    row = tuple(None if pd.isna(x) else x for x in row)
    cursor.execute(sql, row)

cnx.commit()
cursor.close()
cnx.close()

print("✅ Đã insert df_final_detail vào etf_asset_detail_train thành công!")
